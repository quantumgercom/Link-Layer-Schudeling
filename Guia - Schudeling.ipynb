# %% [markdown]
#   ### Importando as dependências

# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger

# %% [markdown]
# ### Instanciando a rede, setando a topologia e ativando o log

# %%
rede = Network()
rede.set_ready_topology("Grade", 3,4)
rede.draw()
Logger.activate(Logger)
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %% [markdown]
# #### Pegando alice e bob como os nós 1, 2 respectivamente

# %%
alice = rede.get_host(1)
bob = rede.get_host(2)

# %% [markdown]
# ### Função de verificação do canal, para sabermos o estado do canal

# %%
rede.get_channel_info(1,2)
# Out:
# {'type': 'XZ',
#  'prob_erro_X': 0.27416767582730484,
#  'prob_erro_Y': 0.0,
#  'prob_erro_Z': 0.3624711027607259,
#  'prob_erro_XZ': 0.22121183153602464}

# %% [markdown]
# ### Função para estimar os rounds dado a fidelidade

# %%
# rede.linklayer.round_estimates(1,2,0.9999999767694274)

# %% [markdown]
# ### Função de verificação de todos os canais da rede, para sabermos o estado de todos os canais

# %%
rede.channels_informations()
# Out:
# Canal entre 0 e 4:
#   Tipo: X
#   Probabilidade de erro X: 0.1737407808997531
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.0
#   Probabilidade de erro XZ: 0.0
# ----------------------------------------
# Canal entre 0 e 1:
#   Tipo: Y
#   Probabilidade de erro X: 0.0
#   Probabilidade de erro Y: 0.45818185818379653
#   Probabilidade de erro Z: 0.0
#   Probabilidade de erro XZ: 0.0
# ----------------------------------------
# Canal entre 1 e 5:
#   Tipo: X
#   Probabilidade de erro X: 0.21439121091617133
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.0
#   Probabilidade de erro XZ: 0.0
# ----------------------------------------
# Canal entre 1 e 2:
#   Tipo: XZ
#   Probabilidade de erro X: 0.27416767582730484
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.3624711027607259
#   Probabilidade de erro XZ: 0.22121183153602464
# ----------------------------------------
# Canal entre 2 e 6:
#   Tipo: Z
#   Probabilidade de erro X: 0.0
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.11388145412861675
#   Probabilidade de erro XZ: 0.0
# ----------------------------------------
# Canal entre 2 e 3:
#   Tipo: Y
#   Probabilidade de erro X: 0.0
#   Probabilidade de erro Y: 0.4075201933741811
#   Probabilidade de erro Z: 0.0
#   Probabilidade de erro XZ: 0.0
# ----------------------------------------
# Canal entre 3 e 7:
#   Tipo: XZ
#   Probabilidade de erro X: 0.3324514677869722
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.30332554275938645
#   Probabilidade de erro XZ: 0.23248484116991752
# ----------------------------------------
# Canal entre 4 e 8:
#   Tipo: XZ
#   Probabilidade de erro X: 0.4158431080699716
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.4238566331293988
#   Probabilidade de erro XZ: 0.29099276581575634
# ----------------------------------------
# Canal entre 4 e 5:
#   Tipo: X
#   Probabilidade de erro X: 0.4391186522294638
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.0
#   Probabilidade de erro XZ: 0.0
# ----------------------------------------
# Canal entre 5 e 9:
#   Tipo: XZ
#   Probabilidade de erro X: 0.22520105832943066
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.46398774483410754
#   Probabilidade de erro XZ: 0.10845987380705889
# ----------------------------------------
# Canal entre 5 e 6:
#   Tipo: X
#   Probabilidade de erro X: 0.2468150034151289
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.0
#   Probabilidade de erro XZ: 0.0
# ----------------------------------------
# Canal entre 6 e 10:
#   Tipo: XZ
#   Probabilidade de erro X: 0.4101226369633738
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.2779445532021048
#   Probabilidade de erro XZ: 0.1335879013336103
# ----------------------------------------
# Canal entre 6 e 7:
#   Tipo: Y
#   Probabilidade de erro X: 0.0
#   Probabilidade de erro Y: 0.34162886331484643
#   Probabilidade de erro Z: 0.0
#   Probabilidade de erro XZ: 0.0
# ----------------------------------------
# Canal entre 7 e 11:
#   Tipo: Y
#   Probabilidade de erro X: 0.0
#   Probabilidade de erro Y: 0.41242493952181336
#   Probabilidade de erro Z: 0.0
#   Probabilidade de erro XZ: 0.0
# ----------------------------------------
# Canal entre 8 e 9:
#   Tipo: XZ
#   Probabilidade de erro X: 0.20206233960320363
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.20079897191860716
#   Probabilidade de erro XZ: 0.2312416201793473
# ----------------------------------------
# Canal entre 9 e 10:
#   Tipo: XZ
#   Probabilidade de erro X: 0.49506113933369333
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.30143324073279587
#   Probabilidade de erro XZ: 0.25441018761035383
# ----------------------------------------
# Canal entre 10 e 11:
#   Tipo: X
#   Probabilidade de erro X: 0.32879675924105417
#   Probabilidade de erro Y: 0.0
#   Probabilidade de erro Z: 0.0
#   Probabilidade de erro XZ: 0.0
# ----------------------------------------

# %%
rede.get_channel_info(1,2)
# Out:
# {'type': 'XZ',
#  'prob_erro_X': 0.27416767582730484,
#  'prob_erro_Y': 0.0,
#  'prob_erro_Z': 0.3624711027607259,
#  'prob_erro_XZ': 0.22121183153602464}

# %%
rede.linklayer.purification_scheduling(1,2,'symmetric',rounds= 4,Policy= 1)
# Out:
# 2024-12-28 00:48:56,148: Iniciando purificação simétrica entre 1 e 2 para 4 rounds.
# 2024-12-28 00:48:56,149: Não há EPRs suficientes para purificação. Necessário: 16, Disponível: 0. Criando 16 EPRs adicionais.
# 2024-12-28 00:48:56,149: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B142998860> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,149: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B142E787D0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,150: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B143FCB6B0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,150: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B143FA7AD0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,150: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B12BCC95E0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,150: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B142F437D0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,150: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B142F408F0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,151: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B12B3D7350> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,151: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B12BBDE030> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,151: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B12B83F350> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,152: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B143FCBB90> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,152: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B143FCBD10> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,152: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B143FC8BC0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,152: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B12B83F800> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,153: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B12B83F620> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,153: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B142CFE8D0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,155: Total de 16 EPRs criados e adicionados ao canal entre 1 e 2.
# 2024-12-28 00:48:56,155: Agora há EPRs suficientes para a purificação: 16 disponíveis.
# 2024-12-28 00:48:56,155: Iniciando purificação auxiliar para backup.
# 2024-12-28 00:48:56,155: Timeslot 0 - Executando round 1 de purificação simétrica.
# 2024-12-28 00:48:56,156: Purificando par de EPRs: fidelidades 0.55 e 0.55.
# 2024-12-28 00:48:56,156: Round 1 - Purificação falhou devido à baixa probabilidade de sucesso: 0.5800000000000001.
# 2024-12-28 00:48:56,156: Par EPR 0 removido do canal (1, 2).
# 2024-12-28 00:48:56,156: Par EPR 1 removido do canal (1, 2).
# 2024-12-28 00:48:56,156: Substituição bem-sucedida. Tentando purificar novamente.
# 2024-12-28 00:48:56,157: Purificando par de EPRs: fidelidades 0.55 e 0.55
# 2024-12-28 00:48:56,157: Round 1 - Probabilidade de sucesso: 0.5800000000000001 (Erro XZ) - Fidelidade: 0.560344827586207
# 2024-12-28 00:48:56,158: Purificando par de EPRs: fidelidades 0.55 e 0.55.
# 2024-12-28 00:48:56,158: Round 1 - Purificação falhou devido à baixa probabilidade de sucesso: 0.5800000000000001.
# 2024-12-28 00:48:56,158: Par EPR 2 removido do canal (1, 2).
# 2024-12-28 00:48:56,158: Par EPR 3 removido do canal (1, 2).
# 2024-12-28 00:48:56,159: Substituição bem-sucedida. Tentando purificar novamente.
# 2024-12-28 00:48:56,159: Purificando par de EPRs: fidelidades 0.55 e 0.55
# 2024-12-28 00:48:56,160: Round 1 - Probabilidade de sucesso: 0.5800000000000001 (Erro XZ) - Fidelidade: 0.560344827586207
# 2024-12-28 00:48:56,160: Purificando par de EPRs: fidelidades 0.55 e 0.55.
# 2024-12-28 00:48:56,160: Round 1 - Probabilidade de sucesso: 0.5800000000000001 (Erro XZ) - Fidelidade: 0.560344827586207
# 2024-12-28 00:48:56,160: Purificando par de EPRs: fidelidades 0.55 e 0.55.
# 2024-12-28 00:48:56,161: Round 1 - Purificação falhou devido à baixa probabilidade de sucesso: 0.5800000000000001.
# 2024-12-28 00:48:56,161: Par EPR 6 removido do canal (1, 2).
# 2024-12-28 00:48:56,161: Par EPR 7 removido do canal (1, 2).
# 2024-12-28 00:48:56,162: Substituição bem-sucedida. Tentando purificar novamente.
# 2024-12-28 00:48:56,162: Purificando par de EPRs: fidelidades 0.55 e 0.55
# 2024-12-28 00:48:56,162: Round 1 - Probabilidade de sucesso: 0.5800000000000001 (Erro XZ) - Fidelidade: 0.560344827586207
# 2024-12-28 00:48:56,163: Purificando par de EPRs: fidelidades 0.55 e 0.55.
# 2024-12-28 00:48:56,163: Round 1 - Purificação falhou devido à baixa probabilidade de sucesso: 0.5800000000000001.
# 2024-12-28 00:48:56,163: Par EPR 8 removido do canal (1, 2).
# 2024-12-28 00:48:56,163: Par EPR 9 removido do canal (1, 2).
# 2024-12-28 00:48:56,163: Substituição bem-sucedida. Tentando purificar novamente.
# 2024-12-28 00:48:56,165: Purificando par de EPRs: fidelidades 0.55 e 0.55
# 2024-12-28 00:48:56,165: Round 1 - Probabilidade de sucesso: 0.5800000000000001 (Erro XZ) - Fidelidade: 0.560344827586207
# 2024-12-28 00:48:56,165: Purificando par de EPRs: fidelidades 0.55 e 0.55.
# 2024-12-28 00:48:56,166: Round 1 - Probabilidade de sucesso: 0.5800000000000001 (Erro XZ) - Fidelidade: 0.560344827586207
# 2024-12-28 00:48:56,166: Purificando par de EPRs: fidelidades 0.55 e 0.55.
# 2024-12-28 00:48:56,166: Round 1 - Purificação falhou devido à baixa probabilidade de sucesso: 0.5800000000000001.
# 2024-12-28 00:48:56,166: Par EPR 12 removido do canal (1, 2).
# 2024-12-28 00:48:56,167: Par EPR 13 removido do canal (1, 2).
# 2024-12-28 00:48:56,167: Substituição bem-sucedida. Tentando purificar novamente.
# 2024-12-28 00:48:56,167: Purificando par de EPRs: fidelidades 0.55 e 0.55
# 2024-12-28 00:48:56,168: Round 1 - Probabilidade de sucesso: 0.5800000000000001 (Erro XZ) - Fidelidade: 0.560344827586207
# 2024-12-28 00:48:56,168: Purificando par de EPRs: fidelidades 0.55 e 0.55.
# 2024-12-28 00:48:56,168: Round 1 - Probabilidade de sucesso: 0.5800000000000001 (Erro XZ) - Fidelidade: 0.560344827586207
# 2024-12-28 00:48:56,169: Par EPR 0 removido do canal (1, 2).
# 2024-12-28 00:48:56,169: Par EPR 1 removido do canal (1, 2).
# 2024-12-28 00:48:56,169: Par EPR 2 removido do canal (1, 2).
# 2024-12-28 00:48:56,170: Par EPR 3 removido do canal (1, 2).
# 2024-12-28 00:48:56,170: Par EPR 4 removido do canal (1, 2).
# 2024-12-28 00:48:56,170: Par EPR 5 removido do canal (1, 2).
# 2024-12-28 00:48:56,170: Par EPR 6 removido do canal (1, 2).
# 2024-12-28 00:48:56,170: Par EPR 7 removido do canal (1, 2).
# 2024-12-28 00:48:56,170: Par EPR 8 removido do canal (1, 2).
# 2024-12-28 00:48:56,171: Par EPR 9 removido do canal (1, 2).
# 2024-12-28 00:48:56,171: Par EPR 10 removido do canal (1, 2).
# 2024-12-28 00:48:56,172: Par EPR 11 removido do canal (1, 2).
# 2024-12-28 00:48:56,172: Par EPR 12 removido do canal (1, 2).
# 2024-12-28 00:48:56,172: Par EPR 13 removido do canal (1, 2).
# 2024-12-28 00:48:56,172: Par EPR 14 removido do canal (1, 2).
# 2024-12-28 00:48:56,173: Par EPR 15 removido do canal (1, 2).
# 2024-12-28 00:48:56,173: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B142F8FDA0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,173: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B142F8FBF0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,173: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B143FA41A0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,174: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B143FA6960> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,174: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B12B83F9E0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,176: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B143FA6060> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,176: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B142F8EBA0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,176: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B143FDD760> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,176: Round 1: Decoerência não aplicada (primeiro round).
# 2024-12-28 00:48:56,176: Round 1 de purificação concluído com sucesso.
# 2024-12-28 00:48:56,176: Timeslot 1 - Executando round 2 de purificação simétrica.
# 2024-12-28 00:48:56,176: Purificando par de EPRs: fidelidades 0.560344827586207 e 0.560344827586207.
# 2024-12-28 00:48:56,178: Round 2 - Purificação falhou devido à baixa probabilidade de sucesso: 0.5856123662306778.
# 2024-12-28 00:48:56,178: Par EPR 64 removido do canal (1, 2).
# 2024-12-28 00:48:56,178: Par EPR 65 removido do canal (1, 2).
# 2024-12-28 00:48:56,179: Substituição bem-sucedida. Tentando purificar novamente.
# 2024-12-28 00:48:56,179: Purificando par de EPRs: fidelidades 0.560344827586207 e 0.560344827586207
# 2024-12-28 00:48:56,179: Round 2 - Probabilidade de sucesso: 0.5856123662306778 (Erro XZ) - Fidelidade: 0.560344827586207
# 2024-12-28 00:48:56,179: Purificando par de EPRs: fidelidades 0.560344827586207 e 0.560344827586207.
# 2024-12-28 00:48:56,180: Round 2 - Probabilidade de sucesso: 0.5856123662306778 (Erro XZ) - Fidelidade: 0.5728426395939087
# 2024-12-28 00:48:56,180: Purificando par de EPRs: fidelidades 0.560344827586207 e 0.560344827586207.
# 2024-12-28 00:48:56,180: Round 2 - Purificação falhou devido à baixa probabilidade de sucesso: 0.5856123662306778.
# 2024-12-28 00:48:56,180: Par EPR 68 removido do canal (1, 2).
# 2024-12-28 00:48:56,181: Par EPR 69 removido do canal (1, 2).
# 2024-12-28 00:48:56,181: Substituição bem-sucedida. Tentando purificar novamente.
# 2024-12-28 00:48:56,181: Purificando par de EPRs: fidelidades 0.560344827586207 e 0.560344827586207
# 2024-12-28 00:48:56,181: Round 2 - Probabilidade de sucesso: 0.5856123662306778 (Erro XZ) - Fidelidade: 0.560344827586207
# 2024-12-28 00:48:56,182: Purificando par de EPRs: fidelidades 0.560344827586207 e 0.560344827586207.
# 2024-12-28 00:48:56,182: Round 2 - Purificação falhou devido à baixa probabilidade de sucesso: 0.5856123662306778.
# 2024-12-28 00:48:56,182: Par EPR 70 removido do canal (1, 2).
# 2024-12-28 00:48:56,182: Par EPR 71 removido do canal (1, 2).
# 2024-12-28 00:48:56,182: Substituição bem-sucedida. Tentando purificar novamente.
# 2024-12-28 00:48:56,182: Purificando par de EPRs: fidelidades 0.560344827586207 e 0.560344827586207
# 2024-12-28 00:48:56,184: Round 2 - Probabilidade de sucesso: 0.5856123662306778 (Erro XZ) - Fidelidade: 0.560344827586207
# 2024-12-28 00:48:56,184: Par EPR 64 removido do canal (1, 2).
# 2024-12-28 00:48:56,184: Par EPR 65 removido do canal (1, 2).
# 2024-12-28 00:48:56,184: Par EPR 66 removido do canal (1, 2).
# 2024-12-28 00:48:56,185: Par EPR 67 removido do canal (1, 2).
# 2024-12-28 00:48:56,185: Par EPR 68 removido do canal (1, 2).
# 2024-12-28 00:48:56,185: Par EPR 69 removido do canal (1, 2).
# 2024-12-28 00:48:56,185: Par EPR 70 removido do canal (1, 2).
# 2024-12-28 00:48:56,185: Par EPR 71 removido do canal (1, 2).
# 2024-12-28 00:48:56,185: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B142CFE8D0> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,185: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B142998860> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,187: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B143FA5940> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,187: Par EPR <quantumnet.objects.epr.Epr object at 0x000001B143FDF170> adicionado ao canal (1, 2).
# 2024-12-28 00:48:56,187: Round 2: Decoerência aplicada (round intermediário).
# 2024-12-28 00:48:56,187: Round 2 de purificação concluído com sucesso.
# 2024-12-28 00:48:56,187: Timeslot 2 - Executando round 3 de purificação simétrica.
# 2024-12-28 00:48:56,187: Purificando par de EPRs: fidelidades 0.5671142131979696 e 0.5671142131979696.
# 2024-12-28 00:48:56,188: Round 3 - Probabilidade de sucesso: 0.5893879326330376 (Erro XZ) - Fidelidade: 0.5810089324261107
# 2024-12-28 00:48:56,188: Purificando par de EPRs: fidelidades 0.5671142131979696 e 0.5671142131979696.
# 2024-12-28 00:48:56,188: Round 3 - Purificação falhou devido à baixa probabilidade de sucesso: 0.5893879326330376.
# 2024-12-28 00:48:56,188: Erro: Não há backups suficientes para substituir os pares falhados.
# False

# %% [markdown]
# ### Função de agendamento de purificação, nesta função é verificado se o canal está pronto para purificação, se sim, é agendado a purificação, além disso podemos escolher entre a purifição simétrica ou pumping, e quantidade de rounds desejados

# %%
# rede.linklayer.purification_scheduling(1,2,'simetric',3)

# %% [markdown]
# ### Função de agendamento de verificação para verificar quantos eprs são necessários para purificar o canal

# %%
# rede.linklayer.scheduling_verify(1,2,3)

# %%
rede.get_eprs_from_edge(1,2)
# Out:
# [<quantumnet.objects.epr.Epr at 0x1b142cfe8d0>,
#  <quantumnet.objects.epr.Epr at 0x1b142998860>,
#  <quantumnet.objects.epr.Epr at 0x1b143fa5940>,
#  <quantumnet.objects.epr.Epr at 0x1b143fdf170>]

# %%
# Obter a lista de EPRs entre os nós 1 e 2
eprs = rede.get_eprs_from_edge(1, 2)

# Selecionar o EPR que você deseja medir
epr = eprs[0]

# Medir a fidelidade do EPR
fidelidade = epr.get_current_fidelity()

# Exibir a fidelidade
print(f"A fidelidade do EPR é: {fidelidade}")
# Out:
# A fidelidade do EPR é: 0.5671142131979696

# %%
# # Inicializa a lista para salvar as métricas de cada simulação
# simulation_results = []

# # Loop para rodar a simulação 100 vezes
# for attempt in range(100):
#     # Inicializa a rede e os hosts
#     rede = Network()
#     rede.set_ready_topology("Grade", 3, 4)
#     rede.draw()
#     Logger.activate(Logger)
#     alice = rede.get_host(1)
#     bob = rede.get_host(2)
    
#     # Executa o agendamento de purificação e armazena o sucesso/falha e número de rounds
#     success = rede.linklayer.purification_scheduling(1, 2, 'symmetric', rounds=3, Policy=1)
    
#     # Armazena os resultados da simulação
#     simulation_results.append({
#         "simulation": attempt + 1,
#         "success": success,
#         "rounds": 3  # número de rounds configurado
#     })

# # Exibe os resultados de todas as simulações
# for result in simulation_results:
#     print(f"Simulação {result['simulation']}: {'Sucesso' if result['success'] else 'Falha'}, Rounds: {result['rounds']}")
